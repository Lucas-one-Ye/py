# %% [markdown]
#
# # 实验题目：Pandas数据处理
#
#     班级：          学号：            姓名：            日期：2023.5.18
#     （注：请将报告转换成HTML格式再提交）
#
# ## 一、实验目的
#     1. 能够根据实际需求，利用Pandas进行相应的数据处理。
#     2. 掌握不同数据导入导出的方法。
#     3. 能够进行数据清洗、透视。
#     4. 能够对数据进行排序和统计。
#     5. 能够对数据进行区间化（离散化）处理。
#
#
# ## 二、实验内容

# %% [markdown]
# ##  1. 数据操作

# %% [markdown]
# （1）读取香港酒店数据。

# %%
import pandas as pd 
df=pd.read_excel('香港酒店数据.xlsx')
df
# Out:
#                                                    名字    类型  城市   地区  \
# 0                 香港嘉湖海逸酒店(Harbour Plaza Resort City)  休闲度假  香港   元朗
# 1      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 2                                  香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 3                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 4                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# ..                                                ...   ...  ..  ...
# 415                       香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港  油尖旺
# 416                               香港AMR宾馆(AMR Hostel)  地铁周边  香港  NaN
# 417  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 418  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 419                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
#
#                         地点   评分     评分人数     价格
# 0                天水围天恩路18号  4.6  17604.0  422.0
# ...

# %% [markdown]
# （2）查看所有类型为“浪漫情侣”，地区在湾仔的酒店。

# %%
(df.类型=='浪漫情侣') & (df.地区=='湾仔')
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %%
df[(df.类型=='浪漫情侣') & (df.地区=='湾仔')]
# Out:
#                                                     名字    类型  城市  地区  \
# 3                            香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港  湾仔
# 5               香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港  湾仔
# 23                         香港南洋酒店(South Pacific Hotel)  浪漫情侣  香港  湾仔
# 35                       香港遨舍卫兰轩(OZO Wesley Hong Kong)  浪漫情侣  香港  湾仔
# 67                     香港星网商务精品酒店(Wifi Boutique Hotel)  浪漫情侣  香港  湾仔
# 72                    香港丽骏酒店(Brighton Hotel Hong Kong)  浪漫情侣  香港  湾仔
# 123                       香港逸兰精品酒店(Lanson Place Hotel)  浪漫情侣  香港  湾仔
# 128                   香港珀丽酒店(Rosedale Hotel Hong Kong)  浪漫情侣  香港  湾仔
# 133                   英皇骏景酒店(香港湾仔店)(The Emperor Hotel)  浪漫情侣  香港  湾仔
# 159  香港华丽铜锣湾酒店(原香港华丽精品酒店)(Best Western Hotel Causew...  浪漫情侣  香港  湾仔
# 160  香港铜锣湾智选假日酒店(Holiday Inn Express Hong Kong Caus...  浪漫情侣  香港  湾仔
# 182                        香港问月酒店(Mira Moon Hong Kong)  浪漫情侣  香港  湾仔
# 183                        帆船精品酒店(VELA BOUTIQUE HOTEL)  浪漫情侣  香港  湾仔
# ...

# %% [markdown]
# （3）查看所有地区在观塘或者油尖旺，评分大于4的酒店。

# %%
df[((df.地区=='观塘')|(df.地区=='油尖旺')) & (df.评分>4)  ]
# Out:
#                                                     名字    类型  城市   地区  \
# 2                                   香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 4                                 如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# 6    海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...  海滨风光  香港  油尖旺
# 8                        香港富豪九龙酒店(Regal Kowloon Hotel)  休闲度假  香港  油尖旺
# 10                    香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  地铁周边  香港  油尖旺
# ..                                                 ...   ...  ..  ...
# 363                  香港珊瑚酒店(家庭旅馆)((Coral Inn)(Hostel))  地铁周边  香港  油尖旺
# 372                                   香港意乐旅馆(eLog Inn)  地铁周边  香港  油尖旺
# 378               香港牛津尊贵旅舍(Oxford Premium Guest House)   NaN  香港  油尖旺
# 379                             香港恒好宾馆(Hang Ho Hostel)  地铁周边  香港  油尖旺
# 395                          香港御珑馆(家庭旅馆)(Hotel Conext)  地铁周边  香港  油尖旺
#
#                                地点   评分     评分人数      价格
# 2                      九龙旺角洗衣街88号  4.7    328.0   747.0
# ...

# %% [markdown]
# （4）查看“类型”缺失的数据。

# %%
df['类型'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: 类型, Length: 420, dtype: bool

# %%
df[df['类型'].isnull()]
# Out:
#                                                    名字   类型  城市   地区  \
# 39          香港颐庭酒店(铜锣湾店)(Eco Tree Hotel Causeway Bay)  NaN  香港   东区
# 187                                  工業家酒店(IND Hotel)  NaN  香港   观塘
# 200                        香港永倫800酒店(WINLAND800HOTEL)  NaN  香港   葵青
# 241                    香港港湾酒店(Hong Kong Harbor Hotel)  NaN  香港   南区
# 268                                  香港奥斯酒店(O‘ Hotel)  NaN  香港  九龙城
# 284                巴黎旅馆(Paris Guest House (D2, 10/F))  NaN  香港  NaN
# 300        香港海景渡假乐园(Hong Kong Seaview Holiday Resort)  NaN  香港   离岛
# 301                           香港海边小屋(The Cove Hostel)  NaN  香港   离岛
# 304                      香港和平宾馆(HK Peace Guest House)  NaN  香港  NaN
# 306                            香港文苑宾馆(Man Yuen Hotel)  NaN  香港  油尖旺
# 315                           墨尔本宾馆(Melbourne Hostel)  NaN  香港  NaN
# 318                          香港百丽旅馆(Park Guest House)  NaN  香港  油尖旺
# 321             香港尊贵旅馆(Hong Kong Premium Guest House)  NaN  香港  油尖旺
# ...

# %% [markdown]
# （5）用“其他”填充类型和地区。

# %%
df['类型'].fillna('其他',inplace=True) 
df
# Out:
#                                                    名字    类型  城市   地区  \
# 0                 香港嘉湖海逸酒店(Harbour Plaza Resort City)  休闲度假  香港   元朗
# 1      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 2                                  香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 3                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 4                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# ..                                                ...   ...  ..  ...
# 415                       香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港  油尖旺
# 416                               香港AMR宾馆(AMR Hostel)  地铁周边  香港  NaN
# 417  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 418  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 419                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
#
#                         地点   评分     评分人数     价格
# 0                天水围天恩路18号  4.6  17604.0  422.0
# ...

# %%
df.fillna({'类型':'其他','地区':'其他'},inplace=True)

# %% [markdown]
# （6）用“评分”均值填充评分列的缺失值。

# %%
df['评分'].fillna(df.评分.mean(),inplace=True)

# %%
df.fillna({'评分':df.评分.mean()},inplace=True)

# %% [markdown]
# （7）删除“价格”和“评分人数”的缺失值。

# %%
df.dropna(subset=['价格','评分人数'],inplace=True)

# %%
data = data.dropna(axis=0,subset=['价格','评分人数'])
data[data['价格'].isnull()]
data[data['评分人数'].isnull()]
data.index = range(len(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7400\2786995139.py in <module>
# ----> 1 data = data.dropna(axis=0,subset=['价格','评分人数'])
#       2 data[data['价格'].isnull()]
#       3 data[data['评分人数'].isnull()]
#       4 data.index = range(len(data))
#
# NameError: name 'data' is not defined

# %%
print(df[df['价格'].isnull()])
print(df[df['评分人数'].isnull()])
#删除价格和评分人数的缺失值的行
df=df.dropna()
# Out:
# Empty DataFrame
# Columns: [名字, 类型, 城市, 地区, 地点, 评分, 评分人数, 价格]
# Index: []
# Empty DataFrame
# Columns: [名字, 类型, 城市, 地区, 地点, 评分, 评分人数, 价格]
# Index: []

# %%
df['价格'].dropna(inplace=True)
df['评分人数'].dropna(inplace=True)

# %% [markdown]
# （8）保存到“酒店数据1.xlsx”。

# %%
df.to_excel('酒店数据1.xlsx',index=False)

# %% [markdown]
# # 2. Pandas数据排序和基本统计

# %% [markdown]
# （1）读取酒店数据1.xlsx。

# %%
import pandas as pd 
df=pd.read_excel('酒店数据1.xlsx')

# %% [markdown]
# （2）查看“评分”的数据类型，并分别进行升序和降序排序。

# %%
df['评分'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# 名字       object
# 类型       object
# 城市       object
# 地区       object
# 地点       object
# 评分      float64
# 评分人数      int64
# 价格        int64
# dtype: object

# %%
df.sort_values(by='评分')
# Out:
#                                                     名字    类型  城市   地区  \
# 385                      香港中 港酒店(家庭旅馆)(HK-China Hotel)  地铁周边  香港  油尖旺
# 280           香港经济型酒店  (家庭旅馆)(Hong Kong Budget Hostel)  地铁周边  香港  油尖旺
# 282                 巴黎旅馆(Paris Guest House (D2, 10/F))    其他  香港   其他
# 360                    香港港龙酒店(Comfort Lodge Hong Kong)  地铁周边  香港  油尖旺
# 332                  香港欣欣宾馆(家庭旅馆)(YAN YAN GUEST HOUSE)  地铁周边  香港  油尖旺
# 353                                         香港京华宾馆(佐敦)  地铁周边  香港   其他
# 358              香港新中华宾馆(New China Yan Yan Guesthouse)  地铁周边  香港  油尖旺
# 366                   香港尖沙咀大福星光酒店(Tsim Sha Tsui Hotel)  地铁周边  香港  油尖旺
# 374                    香港东方明珠宾馆(Oriental Pearl Hostel)  地铁周边  香港  油尖旺
# 335                                      香港迎酒店(HI-INN)  地铁周边  香港   其他
# 375                               香港摩登宾馆(MODERN HOTEL)  地铁周边  香港   其他
# 297         香港海景渡假乐园(Hong Kong Seaview Holiday Resort)    其他  香港   离岛
# ...

# %% [markdown]
# （3）计算“油尖旺”地区的均价。

# %%
df[df['地区']=='油尖旺']['价格'].mean()
# Out:
# 544.3621621621621

# %% [markdown]
# （4）对酒店数据进行描述性统计，并求所有价格的中值。

# %%
df.describe()
# Out:
#                评分          评分人数            价格
# count  397.000000    397.000000    397.000000
# mean     4.286395   2511.929471    681.659950
# std      0.483998   4566.627028    906.282671
# min      1.500000      1.000000     67.000000
# 25%      4.200000     96.000000    247.000000
# 50%      4.400000    869.000000    418.000000
# 75%      4.600000   3283.000000    766.000000
# max      4.900000  45463.000000  12926.000000

# %%
df['价格'].median()
# Out:
# 418.0

# %% [markdown]
# （5）计算评分和价格之间的的相关系数。

# %%
import numpy as np
xs=np.corrcoef(df['评分'],df['价格'])
xs
# Out:
# array([[1.        , 0.28818875],
#        [0.28818875, 1.        ]])

# %%
df[['评分','价格']].corr()
# Out:
#           评分        价格
# 评分  1.000000  0.288189
# 价格  0.288189  1.000000

# %% [markdown]
# （6）按照评分降序排序，评分相同时按价格升序排序。

# %%
df.sort_values(['评分','价格'],ascending=[False,True])
# Out:
#                                            名字    类型  城市   地区  \
# 211          香港李女士宾馆(家庭旅馆)(MS LI GUEST HOUSE)  地铁周边  香港  油尖旺
# 333     香港新金冠宾馆(New Golden Crown Guest House)    客栈  香港  油尖旺
# 317     香港尊贵旅馆(Hong Kong Premium Guest House)    其他  香港  油尖旺
# 199                        香港鸣人宾馆(Naruto Inn)  地铁周边  香港  油尖旺
# 75             香港和平客栈(HK Peaceful Guesthouse)    民宿  香港   其他
# ..                                        ...   ...  ..  ...
# 332         香港欣欣宾馆(家庭旅馆)(YAN YAN GUEST HOUSE)  地铁周边  香港  油尖旺
# 360           香港港龙酒店(Comfort Lodge Hong Kong)  地铁周边  香港  油尖旺
# 280  香港经济型酒店  (家庭旅馆)(Hong Kong Budget Hostel)  地铁周边  香港  油尖旺
# 282        巴黎旅馆(Paris Guest House (D2, 10/F))    其他  香港   其他
# 385             香港中 港酒店(家庭旅馆)(HK-China Hotel)  地铁周边  香港  油尖旺
#
#                                                     地点   评分  评分人数   价格
# 211                                弥敦道58号美丽都大厦E座5字楼E1室  4.9     7  351
# 333                                 尖沙咀弥敦道68号金冠大厦13楼C室  4.9    10  395
# ...

# %% [markdown]
# （7）计算一下，评分小于3分的酒店数量和占比。

# %%
len(df[df['评分']<3])
# Out:
# 12

# %%
len(df[df['评分']<3])/len(df)
# Out:
# 0.030226700251889168

# %% [markdown]
# （8）计算一下，酒店评分大于等于4分的酒店的价格均值。

# %%
df[df['评分']>=4]['价格'].mean()
# Out:
# 742.2205882352941

# %% [markdown]
# （9）计算出每个地区的酒店占总酒店数量的比例。

# %%
df['地区'].value_counts()
# Out:
# 油尖旺     185
# 其他       56
# 湾仔       41
# 中西区      33
# 九龙城      21
# 东区       16
# 离岛       11
# 观塘        7
# 荃湾        7
# 南区        5
# 葵青        5
# 沙田        4
# 元朗        2
# 屯门        2
# 深水埗区      1
# 罗湖区       1
# Name: 地区, dtype: int64

# %%
df['地区'].value_counts()/len(df)
# Out:
# 油尖旺     0.465995
# 其他      0.141058
# 湾仔      0.103275
# 中西区     0.083123
# 九龙城     0.052897
# 东区      0.040302
# 离岛      0.027708
# 荃湾      0.017632
# 观塘      0.017632
# 南区      0.012594
# 葵青      0.012594
# 沙田      0.010076
# 屯门      0.005038
# 元朗      0.005038
# 罗湖区     0.002519
# 深水埗区    0.002519
# Name: 地区, dtype: float64

# %% [markdown]
# （10）找出酒店评分人数排名前20的酒店，并计算他们的价格均值。

# %%
df.sort_values('评分人数',ascending=False)[:20]['价格'].mean()
# Out:
# 1110.55

# %% [markdown]
# （11）查看酒店分布地区数量，并统计各地区包含的酒店数量。

# %%
df['地区'].unique()
# Out:
# array(['元朗', '东区', '油尖旺', '湾仔', '观塘', '中西区', '南区', '离岛', '九龙城', '荃湾',
#        '屯门', '葵青', '其他', '沙田', '深水埗区', '罗湖区'], dtype=object)

# %%
len(df['地区'].unique())
# Out:
# 16

# %%
df['地区'].value_counts()
# Out:
# 油尖旺     185
# 其他       56
# 湾仔       41
# 中西区      33
# 九龙城      21
# 东区       16
# 离岛       11
# 观塘        7
# 荃湾        7
# 南区        5
# 葵青        5
# 沙田        4
# 元朗        2
# 屯门        2
# 深水埗区      1
# 罗湖区       1
# Name: 地区, dtype: int64

# %% [markdown]
# （12）用数据透视表，计算每个地区酒店价格和评分的最大值和最小值。

# %%
import pandas as pd 
import numpy as np
pd.pivot_table(df,index=['地区'],values=['价格','评分'],aggfunc=[np.max,np.min])
# Out:
#        amax           amin
#          价格        评分   价格        评分
# 地区
# 东区     1908  4.700000  331  4.200000
# 中西区   12926  4.800000  254  3.800000
# 九龙城    1742  4.800000  137  3.700000
# 元朗      425  4.600000  422  4.500000
# 其他     1450  4.800000   67  2.000000
# 南区      553  4.400000  185  3.800000
# 屯门      696  4.700000  582  4.500000
# 沙田     1052  4.700000  569  4.400000
# 油尖旺    3862  4.900000   67  1.500000
# 深水埗区    648  4.300000  648  4.300000
# 湾仔     2856  4.700000  131  3.400000
# 离岛     1667  4.800000  352  2.900000
# 罗湖区     506  4.283827  506  4.283827
# 荃湾      709  4.500000  225  4.300000
# 葵青      423  4.400000  196  3.400000
# 观塘     1132  4.600000  448  4.200000

# %% [markdown]
# # 3. 数据离散化

# %% [markdown]
# 将酒店数据表添加一列“级别”，级别按照评分[0，2，3，4，4.5，5]分为"1星","2星","3星","4星","5星"五个级别。

# %%
import pandas as pd
df['级别']=pd.cut(df['评分'],[0,2,3,4,4.5,5],labels=["1星","2星","3星","4星","5星"])

# %%
df
# Out:
#                                                    名字    类型  城市   地区  \
# 0                 香港嘉湖海逸酒店(Harbour Plaza Resort City)  休闲度假  香港   元朗
# 1      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 2                                  香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 3                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 4                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# ..                                                ...   ...  ..  ...
# 392                                            香港金泉酒店  地铁周边  香港   其他
# 393                       香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港  油尖旺
# 394  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 395  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 396                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
#
#                        地点        评分   评分人数   价格  级别
# 0               天水围天恩路18号  4.600000  17604  422  5星
# ...
